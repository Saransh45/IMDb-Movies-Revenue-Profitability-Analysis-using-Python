# %% [markdown]
# <a href="https://colab.research.google.com/github/Saransh45/IMDB-Data-Analysis/blob/main/IMDB_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/imdb_data.csv')
data
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
import os

for root, dirs, files in os.walk('/content/drive'):
    if 'imdb_data.csv' in files:
        print(os.path.join(root, 'imdb_data.csv'))
# Out:
# /content/drive/MyDrive/Colab Notebooks/imdb_data.csv

# %%
import os
os.listdir('/content/drive/')
# Out:
# ['MyDrive', '.shortcut-targets-by-id', '.Trash-0', '.Encrypted']

# %%
data.shape
# Out:
# (3000, 23)

# %%
data.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
data.head(100)
# Out:
#      id                              belongs_to_collection    budget  \
# 0     1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1     2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2     3                                                NaN   3300000
# 3     4                                                NaN   1200000
# 4     5                                                NaN         0
# ..  ...                                                ...       ...
# 95   96                                                NaN         0
# 96   97                                                NaN   2500000
# 97   98                                                NaN         0
# 98   99                                                NaN  10500000
# 99  100                                                NaN   6000000
#
#                                                genres  \
# 0                      [{'id': 35, 'name': 'Comedy'}]
# ...

# %%
data.tail(50)
# Out:
#         id                              belongs_to_collection    budget  \
# 2950  2951  [{'id': 9735, 'name': 'Friday the 13th Collect...  30000000
# 2951  2952                                                NaN  13000000
# 2952  2953                                                NaN  25000000
# 2953  2954                                                NaN   8500000
# 2954  2955                                                NaN  60000000
# 2955  2956                                                NaN  17000000
# 2956  2957                                                NaN         0
# 2957  2958                                                NaN  60000000
# 2958  2959                                                NaN  15000000
# 2959  2960                                                NaN   2300000
# 2960  2961                                                NaN   4600000
# 2961  2962  [{'id': 109592, 'name': "Porky's Collection", ...   4000000
# ...

# %%
data.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['id',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'homepage',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'Keywords',
#  'cast',
#  'crew',
#  'revenue']

# %%
data.dtypes
# Out:
# id                         int64
# belongs_to_collection     object
# budget                     int64
# genres                    object
# homepage                  object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# Keywords                  object
# cast                      object
# crew                      object
# revenue                    int64
# dtype: object

# %%
num_data = data.select_dtypes(include =['int64','float64'])

# %%
num_data.columns
# Out:
# Index(['id', 'budget', 'popularity', 'runtime', 'revenue'], dtype='object')

# %%
cat_data = data.select_dtypes(include = ['object'])
cat_data.columns
# Out:
# Index(['belongs_to_collection', 'genres', 'homepage', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'spoken_languages', 'status', 'tagline', 'title', 'Keywords', 'cast',
#        'crew'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
data.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
data.describe(include='object')
# Out:
#                                     belongs_to_collection  \
# count                                                 604
# unique                                                422
# top     [{'id': 645, 'name': 'James Bond Collection', ...
# freq                                                   16
#
#                                genres                           homepage  \
# count                            2993                                946
# unique                            872                                941
# top     [{'id': 18, 'name': 'Drama'}]  http://www.transformersmovie.com/
# freq                              266                                  4
#
#           imdb_id original_language original_title  \
# count        3000              3000           3000
# unique       3000                36           2975
# top     tt1600195                en  Casino Royale
# freq            1              2575              2
#
# ...

# %%
data.isnull()
# Out:
#          id  belongs_to_collection  budget  genres  homepage  imdb_id  \
# 0     False                  False   False   False      True    False
# 1     False                  False   False   False      True    False
# 2     False                   True   False   False     False    False
# 3     False                   True   False   False     False    False
# 4     False                   True   False   False      True    False
# ...     ...                    ...     ...     ...       ...      ...
# 2995  False                   True   False   False      True    False
# 2996  False                   True   False   False      True    False
# 2997  False                   True   False   False      True    False
# 2998  False                   True   False   False     False    False
# 2999  False                   True   False   False     False    False
#
#       original_language  original_title  overview  popularity  ...  \
# ...

# %%
data.isnull().sum()
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# dtype: int64

# %%
data.dropna(inplace= True)

# %%
data.isnull().sum()
# Out:
# id                       0
# belongs_to_collection    0
# budget                   0
# genres                   0
# homepage                 0
# imdb_id                  0
# original_language        0
# original_title           0
# overview                 0
# popularity               0
# poster_path              0
# production_companies     0
# production_countries     0
# release_date             0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# title                    0
# Keywords                 0
# cast                     0
# crew                     0
# revenue                  0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
#data.drop_duplicates()

# %%
data['budget']
# Out:
# 22              0
# 40              0
# 46       80000000
# 60      150000000
# 69       85000000
#           ...
# 2904      4000000
# 2927    140000000
# 2938    130000000
# 2968     25000000
# 2984     80000000
# Name: budget, Length: 203, dtype: int64

# %%
data[['original_language','original_title','overview','popularity']]
# Out:
#      original_language                         original_title  \
# 22                  en                                  V/H/S
# 40                  en                        Cocaine Cowboys
# 46                  en                  Ice Age: The Meltdown
# 60                  en                          Casino Royale
# 69                  en  The Fast and the Furious: Tokyo Drift
# ...                ...                                    ...
# 2904                en                          Trainspotting
# 2927                en                        Die Another Day
# 2938                en                             Prometheus
# 2968                en                             BloodRayne
# 2984                en                               S.W.A.T.
#
#                                                overview  popularity
# 22    When a group of misfits is hired by an unknown...    7.820787
# 40    In the 1980s, ruthless Colombian cocaine baron...    2.941626
# ...

# %%
sliced_df = data.iloc[0:2,2:4]
for col in sliced_df.columns:
    print(f"Unique values in column '{col}':")
    print(sliced_df[col].unique())
# Out:
# Unique values in column 'budget':
# [0]
# Unique values in column 'genres':
# ["[{'id': 53, 'name': 'Thriller'}, {'id': 27, 'name': 'Horror'}]"
#  "[{'id': 28, 'name': 'Action'}, {'id': 99, 'name': 'Documentary'}]"]

# %%
data.iloc[0:2,2].unique()
# Out:
# array([0])

# %%
data.iloc[0:100,2].value_counts()
# Out:
# budget
# 0            9
# 150000000    6
# 6000000      4
# 40000000     4
# 50000000     4
# 200000000    3
# 17000000     3
# 85000000     3
# 20000000     3
# 80000000     2
# 7000000      2
# 30000000     2
# 250000000    2
# 19000000     2
# 5000000      2
# 90000000     2
# 35000000     2
# 15000000     2
# 100000000    2
# 49000000     1
# 10000000     1
# 45000000     1
# 93000000     1
# 32000000     1
# 175000000    1
# 27000        1
# 160000000    1
# 21000000     1
# 7500000      1
# 9000000      1
# 48000000     1
# 79000000     1
# 110000000    1
# 7200000      1
# 103000000    1
# 26000000     1
# 75000000     1
# 2700000      1
# 59000000     1
# 54000000     1
# 57000000     1
# 185000000    1
# 13000000     1
# 113000000    1
# 135000000    1
# 60000000     1
# 800000       1
# 12000000     1
# 5600000      1
# 14000000     1
# 105000000    1
# 58000000     1
# 220000000    1
# 15000        1
# 1500000      1
# 16000000     1
# 65000000     1
# 38000000     1
# ...

# %%
data.iloc[0:2,2:4].value_counts()
# Out:
# budget  genres
# 0       [{'id': 28, 'name': 'Action'}, {'id': 99, 'name': 'Documentary'}]    1
#         [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'name': 'Horror'}]       1
# Name: count, dtype: int64

# %%
type(data.iloc[0:2,2:4].value_counts())
# Out:
# pandas.core.series.Series

# %%
data.iloc[0:2,2:4].value_counts().reset_index()
# Out:
#    budget                                             genres  count
# 0       0  [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...      1
# 1       0  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...      1

# %%
data.sort_values('revenue',ascending=False)
# Out:
#         id                              belongs_to_collection     budget  \
# 1126  1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
# 1761  1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
# 2770  2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 2322  2323  [{'id': 8650, 'name': 'Transformers Collection...  195000000
# 2135  2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
# ...    ...                                                ...        ...
# 514    515  [{'id': 206559, 'name': 'StreetDance Collectio...          0
# 2276  2277  [{'id': 286038, 'name': 'Dead Snow Collection'...          0
# 1499  1500  [{'id': 473843, 'name': 'Stake Land Collection...     650000
# 1563  1564  [{'id': 87186, 'name': 'The Boondock Saints Co...    6000000
# 665    666  [{'id': 86668, 'name': 'Elektra Luxx Collectio...          0
#
#                                                  genres  \
# ...

# %%
data.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
data.rename(columns={'revenue':'Revenue','id':'Id','production_companies':'Companies','production_countries':'Countries'},inplace=True)

# %%
data.columns
# Out:
# Index(['Id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'Companies', 'Countries', 'release_date',
#        'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'Keywords',
#        'cast', 'crew', 'Revenue'],
#       dtype='object')

# %%
data.loc[:,'Profit']=data.loc[:,'Revenue']-data.loc[:,'budget']

# %%
data.head()
# Out:
#     Id                              belongs_to_collection     budget  \
# 22  23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40  41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46  47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60  61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 69  70  [{'id': 9485, 'name': 'The Fast and the Furiou...   85000000
#
#                                                genres  \
# 22  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40  [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 46  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 60  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 69  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                              homepage    imdb_id  \
# 22                http://www.magnetreleasing.com/vhs/  tt2105044
# 40  http://www.magpictures.com/profile.aspx?id=983...  tt0380268
# ...

# %%
data.loc[:,'Half_runtime'] = data.loc[:,'runtime']/2

# %%
data.head()
# Out:
#     Id                              belongs_to_collection     budget  \
# 22  23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40  41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46  47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60  61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 69  70  [{'id': 9485, 'name': 'The Fast and the Furiou...   85000000
#
#                                                genres  \
# 22  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40  [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 46  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 60  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 69  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                              homepage    imdb_id  \
# 22                http://www.magnetreleasing.com/vhs/  tt2105044
# 40  http://www.magpictures.com/profile.aspx?id=983...  tt0380268
# ...

# %%
data.loc[:,'new_released_date']=pd.to_datetime(data.loc[:,'release_date'])
# Out:
# /tmp/ipython-input-455865037.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data.loc[:,'new_released_date']=pd.to_datetime(data.loc[:,'release_date'])

# %%
data.loc[:,'year'] = data.loc[:,'new_released_date'].dt.year

# %%
data.head()
# Out:
#     Id                              belongs_to_collection     budget  \
# 22  23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40  41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46  47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60  61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 69  70  [{'id': 9485, 'name': 'The Fast and the Furiou...   85000000
#
#                                                genres  \
# 22  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40  [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 46  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 60  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 69  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                              homepage    imdb_id  \
# 22                http://www.magnetreleasing.com/vhs/  tt2105044
# 40  http://www.magpictures.com/profile.aspx?id=983...  tt0380268
# ...

# %%
data.loc[:,'month']=data.loc[:,'new_released_date'].dt.month

# %%
data.loc[:,'month_Name']=data.loc[:,'new_released_date'].dt.month_name

# %%
data.loc[:,'day']=data.loc[:,'new_released_date'].dt.day

# %%
data.loc[:,'original_language'].replace({'en','english'},inplace=True)
# Out:
# /tmp/ipython-input-2044314414.py:1: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   data.loc[:,'original_language'].replace({'en','english'},inplace=True)
# /tmp/ipython-input-2044314414.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.loc[:,'original_language'].replace({'en','english'},inplace=True)

# %%
data.loc[:,'original_language'].replace({'hi','hindi'},inplace=True)
# Out:
# /tmp/ipython-input-4239551766.py:1: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   data.loc[:,'original_language'].replace({'hi','hindi'},inplace=True)
# /tmp/ipython-input-4239551766.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.loc[:,'original_language'].replace({'hi','hindi'},inplace=True)

# %%
data.head()
# Out:
#     Id                              belongs_to_collection     budget  \
# 22  23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40  41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46  47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60  61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 69  70  [{'id': 9485, 'name': 'The Fast and the Furiou...   85000000
#
#                                                genres  \
# 22  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40  [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 46  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 60  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 69  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                              homepage    imdb_id  \
# 22                http://www.magnetreleasing.com/vhs/  tt2105044
# 40  http://www.magpictures.com/profile.aspx?id=983...  tt0380268
# ...

# %%
data.loc[data.loc[:,"original_language"]=='english']
# Out:
# Empty DataFrame
# Columns: [Id, belongs_to_collection, budget, genres, homepage, imdb_id, original_language, original_title, overview, popularity, poster_path, Companies, Countries, release_date, runtime, spoken_languages, status, tagline, title, Keywords, cast, crew, Revenue, Profit, Half_runtime, new_released_date, year, month, month_Name, day]
# Index: []
#
# [0 rows x 30 columns]

# %%
data.loc[data.loc[:,"original_language"]=='hindi']
# Out:
# Empty DataFrame
# Columns: [Id, belongs_to_collection, budget, genres, homepage, imdb_id, original_language, original_title, overview, popularity, poster_path, Companies, Countries, release_date, runtime, spoken_languages, status, tagline, title, Keywords, cast, crew, Revenue, Profit, Half_runtime, new_released_date, year, month, month_Name, day]
# Index: []
#
# [0 rows x 30 columns]

# %%
data.loc[data.loc[:,"year"]>2014]
# Out:
#         Id                              belongs_to_collection     budget  \
# 294    295  [{'id': 131635, 'name': 'The Hunger Games Coll...  160000000
# 314    315  [{'id': 87118, 'name': 'Cars Collection', 'pos...  175000000
# 351    352  [{'id': 645, 'name': 'James Bond Collection', ...    7200000
# 514    515  [{'id': 206559, 'name': 'StreetDance Collectio...          0
# 548    549  [{'id': 426103, 'name': 'Ouija Collection', 'p...    9000000
# 699    700  [{'id': 376650, 'name': 'Ride Along Collection...   40000000
# 809    810  [{'id': 115776, 'name': 'Robert Langdon Collec...   75000000
# 818    819  [{'id': 167613, 'name': 'Alvin and the Chipmun...          0
# 837    838  [{'id': 8945, 'name': 'Mad Max Collection', 'p...  150000000
# 1038  1039  [{'id': 401562, 'name': 'Teenage Mutant Ninja ...  135000000
# 1093  1094  [{'id': 230, 'name': 'The Godfather Collection...    6000000
# 1124  1125  [{'id': 8354, 'name': 'Ice Age Collection', 'p...  105000000
# ...

# %%
data.loc[(data.loc[:,'year']=='2012') | (data.loc[:,'year']=='2013')]
# Out:
# Empty DataFrame
# Columns: [Id, belongs_to_collection, budget, genres, homepage, imdb_id, original_language, original_title, overview, popularity, poster_path, Companies, Countries, release_date, runtime, spoken_languages, status, tagline, title, Keywords, cast, crew, Revenue, Profit, Half_runtime, new_released_date, year, month, month_Name, day]
# Index: []
#
# [0 rows x 30 columns]

# %%
def to_uppercase(column):
  return column.upper()

data.loc[:,"capitalized_title"] = data.loc[:,"title"].apply(to_uppercase)

# %%
data.head()
# Out:
#     Id                              belongs_to_collection     budget  \
# 22  23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40  41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46  47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60  61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 69  70  [{'id': 9485, 'name': 'The Fast and the Furiou...   85000000
#
#                                                genres  \
# 22  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40  [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 46  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 60  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 69  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                              homepage    imdb_id  \
# 22                http://www.magnetreleasing.com/vhs/  tt2105044
# 40  http://www.magpictures.com/profile.aspx?id=983...  tt0380268
# ...

# %%
data.loc[:,'original_title']= data.loc[:,'original_title'].apply(to_uppercase)

# %%
data.head()
# Out:
#     Id                              belongs_to_collection     budget  \
# 22  23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40  41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46  47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60  61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 69  70  [{'id': 9485, 'name': 'The Fast and the Furiou...   85000000
#
#                                                genres  \
# 22  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40  [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 46  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 60  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 69  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                              homepage    imdb_id  \
# 22                http://www.magnetreleasing.com/vhs/  tt2105044
# 40  http://www.magpictures.com/profile.aspx?id=983...  tt0380268
# ...

# %%
data.columns
# Out:
# Index(['Id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'Companies', 'Countries', 'release_date',
#        'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'Keywords',
#        'cast', 'crew', 'Revenue', 'Profit', 'Half_runtime',
#        'new_released_date', 'year', 'month', 'month_Name', 'day',
#        'capitalized_title'],
#       dtype='object')

# %%
def to_lowercase(value):
  if isinstance(value,str):
    return value.lower()
  return value

# %%
isinstance("hello",str)
# Out:
# True

# %%
isinstance(2,int)
# Out:
# True

# %%
data.loc[:,'tagline'] = data.loc[:,'tagline'].apply(to_lowercase)

# %%
data.head()
# Out:
#     Id                              belongs_to_collection     budget  \
# 22  23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40  41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46  47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60  61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 69  70  [{'id': 9485, 'name': 'The Fast and the Furiou...   85000000
#
#                                                genres  \
# 22  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40  [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 46  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 60  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 69  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                              homepage    imdb_id  \
# 22                http://www.magnetreleasing.com/vhs/  tt2105044
# 40  http://www.magpictures.com/profile.aspx?id=983...  tt0380268
# ...

# %%
def calculate_profit(row):
  return row['Revenue'] - row['budget']

data.loc[:,'profit'] = data.apply(calculate_profit,axis=1)

# %%
data.head()
# Out:
#     Id                              belongs_to_collection     budget  \
# 22  23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40  41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46  47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60  61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 69  70  [{'id': 9485, 'name': 'The Fast and the Furiou...   85000000
#
#                                                genres  \
# 22  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40  [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 46  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 60  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 69  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                              homepage    imdb_id  \
# 22                http://www.magnetreleasing.com/vhs/  tt2105044
# 40  http://www.magpictures.com/profile.aspx?id=983...  tt0380268
# ...

# %%
def revised_profit(revenue,budget):
  return revenue-budget

data['new_profit'] = data.apply(lambda x: revised_profit(x['Revenue'], x['budget']), axis=1)

# %%
data.loc[:,'original_language'] = data.loc[:,'original_language'].apply(lambda x: x.upper())

# %%
data.loc[:,'popularity_new'] = data.loc[:,'popularity'].apply(lambda x: round(x,2))

# %%
data.loc[:,'profit_value'] = data.loc[:,'profit'].apply(lambda x: 'positive' if x>0 else 'negative')

# %%
data.head()
# Out:
#     Id                              belongs_to_collection     budget  \
# 22  23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40  41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46  47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60  61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 69  70  [{'id': 9485, 'name': 'The Fast and the Furiou...   85000000
#
#                                                genres  \
# 22  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40  [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 46  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 60  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 69  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                              homepage    imdb_id  \
# 22                http://www.magnetreleasing.com/vhs/  tt2105044
# 40  http://www.magpictures.com/profile.aspx?id=983...  tt0380268
# ...

# %%
data.columns
# Out:
# Index(['Id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'Companies', 'Countries', 'release_date',
#        'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'Keywords',
#        'cast', 'crew', 'Revenue', 'Profit', 'Half_runtime',
#        'new_released_date', 'year', 'month', 'month_Name', 'day',
#        'capitalized_title', 'profit', 'new_profit', 'popularity_new',
#        'profit_value'],
#       dtype='object')

# %%
data.loc[1:'genres']
# Out:
#         Id                              belongs_to_collection     budget  \
# 22      23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40      41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46      47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60      61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 69      70  [{'id': 9485, 'name': 'The Fast and the Furiou...   85000000
# ...    ...                                                ...        ...
# 2904  2905  [{'id': 424202, 'name': 'Trainspotting Collect...    4000000
# 2927  2928  [{'id': 645, 'name': 'James Bond Collection', ...  140000000
# 2938  2939  [{'id': 135416, 'name': 'Prometheus Collection...  130000000
# 2968  2969  [{'id': 97307, 'name': 'BloodRayne Collection'...   25000000
# 2984  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...   80000000
#
#                                                  genres  \
# ...

# %%
A=[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]
df = pd.json_normalize(A)
df
# Out:
#       id     name
# 0     35   Comedy
# 1     18    Drama
# 2  10751   Family
# 3  10749  Romance

# %%
def func(value,key):
  try:
    j = eval(value)
    df = pd.json_normalize(j)
    names = list(df[key])
    return ",".join(names)
  except:
    return value

# %%
data.loc[:,'genre_names'] = data.loc[:,'genres'].apply(func, key='name')

# %%
A = {"Name":["Ridaa","Zara","Arman"],"Age":[20,23,24]}
class_1 = pd.DataFrame(A)

# %%
A = {"Name":["Arya","Diya","Vibha"],"Age":[30,40,50]}
class_2 = pd.DataFrame(A)

# %%
job = {"salary":[20000,30000,40000],"job":["HR","engineer","Analyst"]}
class_1_job = pd.DataFrame(job)
class_1_job
# Out:
#    salary       job
# 0   20000        HR
# 1   30000  engineer
# 2   40000   Analyst

# %%
class_1
# Out:
#     Name  Age
# 0  Ridaa   20
# 1   Zara   23
# 2  Arman   24

# %%
class_2
# Out:
#     Name  Age
# 0   Arya   30
# 1   Diya   40
# 2  Vibha   50

# %%
combined_rows = pd.concat([class_1, class_2],axis = 0, ignore_index=True)
combined_columns = pd.concat([class_1,class_1_job],axis = 1)
combined_columns,combined_rows
# Out:
# (    Name  Age  salary       job
#  0  Ridaa   20   20000        HR
#  1   Zara   23   30000  engineer
#  2  Arman   24   40000   Analyst,
#      Name  Age
#  0  Ridaa   20
#  1   Zara   23
#  2  Arman   24
#  3   Arya   30
#  4   Diya   40
#  5  Vibha   50)

# %%
employees = pd.DataFrame({
    'EmployeeID' : [101, 102, 103, 104],
    'Name' : ['Alice','Bob','Charlie', 'David'],
    'DepartmentID': [1, 2, 3, 5]
    })
employees
# Out:
#    EmployeeID     Name  DepartmentID
# 0         101    Alice             1
# 1         102      Bob             2
# 2         103  Charlie             3
# 3         104    David             5

# %%
departments = pd.DataFrame({
    'DepartmentID': [1,2,3,4],
    'DepartmentName': ['HR','Engineering','Marketing','Finance'],
    'Location': ['New York', 'San Francisco', 'Chicago','Boston']
})
departments
# Out:
#    DepartmentID DepartmentName       Location
# 0             1             HR       New York
# 1             2    Engineering  San Francisco
# 2             3      Marketing        Chicago
# 3             4        Finance         Boston

# %%
inner_merge = pd.merge(employees, departments, on='DepartmentID', how='inner')
inner_merge
# Out:
#    EmployeeID     Name  DepartmentID DepartmentName       Location
# 0         101    Alice             1             HR       New York
# 1         102      Bob             2    Engineering  San Francisco
# 2         103  Charlie             3      Marketing        Chicago

# %%
left_merge = pd.merge(employees, departments, on='DepartmentID', how='left')
left_merge
# Out:
#    EmployeeID     Name  DepartmentID DepartmentName       Location
# 0         101    Alice             1             HR       New York
# 1         102      Bob             2    Engineering  San Francisco
# 2         103  Charlie             3      Marketing        Chicago
# 3         104    David             5            NaN            NaN

# %%
right_merge = pd.merge(employees, departments, on='DepartmentID', how='right')
right_merge
# Out:
#    EmployeeID     Name  DepartmentID DepartmentName       Location
# 0       101.0    Alice             1             HR       New York
# 1       102.0      Bob             2    Engineering  San Francisco
# 2       103.0  Charlie             3      Marketing        Chicago
# 3         NaN      NaN             4        Finance         Boston

# %%
outer_merge = pd.merge(employees, departments, on='DepartmentID', how='outer')
outer_merge
# Out:
#    EmployeeID     Name  DepartmentID DepartmentName       Location
# 0       101.0    Alice             1             HR       New York
# 1       102.0      Bob             2    Engineering  San Francisco
# 2       103.0  Charlie             3      Marketing        Chicago
# 3         NaN      NaN             4        Finance         Boston
# 4       104.0    David             5            NaN            NaN

# %%
data.loc[:,'release_date'] = pd.to_datetime(data.loc[:,'release_date'])
# Out:
# /tmp/ipython-input-1722189326.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data.loc[:,'release_date'] = pd.to_datetime(data.loc[:,'release_date'])

# %%
data.loc[:,'release_year'] = pd.to_datetime(data.loc[:,'release_date']).dt.year

# %%
data.head()
# Out:
#     Id                              belongs_to_collection     budget  \
# 22  23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40  41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46  47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60  61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 69  70  [{'id': 9485, 'name': 'The Fast and the Furiou...   85000000
#
#                                                genres  \
# 22  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40  [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 46  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 60  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 69  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                              homepage    imdb_id  \
# 22                http://www.magnetreleasing.com/vhs/  tt2105044
# 40  http://www.magpictures.com/profile.aspx?id=983...  tt0380268
# ...

# %%
data.groupby('release_year')['Revenue'].sum()
# Out:
# release_year
# 1975     583546319
# 1977     185438673
# 1979     104931801
# 1981     245557502
# 1984     411371200
# 1985     152427960
# 1987     405140171
# 1988       7282851
# 1989    1002823860
# 1990     381293645
# 1992     352927224
# 1993     920100000
# 1994     801164564
# 1995     446409952
# 1996      84605061
# 1997     333011068
# 1999    1191812141
# 2000     127879550
# 2001    1150797240
# 2002    2659232022
# 2003     983251296
# 2004    1573792676
# 2005    2042091705
# 2006    2347970243
# 2007    3103397036
# 2008    3116785148
# 2009    5044521315
# 2010    3124718173
# 2011    4055518627
# 2012    5192265377
# 2013    3408564261
# 2014    4066477009
# 2015    5422508761
# 2016    3418418977
# 2017    2271517194
# 2065     141195658
# 2067     111584787
# 2071     116019547
# 2072     245066411
# 2073     441306145
# Name: Revenue, dtype: int64

# %%
data.groupby('original_language')['Revenue'].sum()
# Out:
# original_language
# CN       21888598
# EN    61061419991
# ES       49107680
# FR        9584131
# ID        2627209
# JA      377352903
# KO       23803308
# NO        2022135
# RU       38862717
# SV       66995253
# ZH      121059225
# Name: Revenue, dtype: int64

# %%
data.groupby('release_year')[['Revenue','budget']].sum()
# Out:
#                  Revenue      budget
# release_year
# 1975           583546319     8200000
# 1977           185438673    14000000
# 1979           104931801    11000000
# 1981           245557502    34000000
# 1984           411371200    34400000
# 1985           152427960    30000000
# 1987           405140171    46000000
# 1988             7282851     3000000
# 1989          1002823860   130000000
# 1990           381293645    94000000
# 1992           352927224    49000000
# 1993           920100000    63000000
# 1994           801164564    80027000
# 1995           446409952    76500000
# 1996            84605061    73000000
# 1997           333011068   110000000
# 1999          1191812141   321060000
# 2000           127879550    99000000
# 2001          1150797240   273000000
# 2002          2659232022   491000000
# 2003           983251296   264000000
# 2004          1573792676   442700000
# 2005          2042091705   553000000
# 2006          2347970243   579580000
# ...

# %%
data.groupby('release_year')['runtime'].max().reset_index()
# Out:
#     release_year  runtime
# 0           1975    124.0
# 1           1977    125.0
# 2           1979    117.0
# 3           1981    127.0
# 4           1984    118.0
# 5           1985    131.0
# 6           1987    130.0
# 7           1988     97.0
# 8           1989    133.0
# 9           1990    162.0
# 10          1992    127.0
# 11          1993    127.0
# 12          1994     92.0
# 13          1995    130.0
# 14          1996    108.0
# 15          1997    119.0
# 16          1999    128.0
# 17          2000     93.0
# 18          2001    178.0
# 19          2002    179.0
# 20          2003    143.0
# 21          2004    132.0
# 22          2005    140.0
# 23          2006    144.0
# 24          2007    169.0
# 25          2008    152.0
# 26          2009    153.0
# 27          2010    133.0
# 28          2011    154.0
# 29          2012    169.0
# 30          2013    161.0
# 31          2014    150.0
# 32          2015    148.0
# 33          2016    134.0
# ...

# %%
employees = pd.DataFrame({
    'EmployeeID': [101, 102, 103, 104],
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'DepartmentID': [1, 2, 3, 5]
}).set_index('DepartmentID')
departments = pd.DataFrame({
    'DepartmentID': [1, 2, 3, 4],
    'DepartmentName': ['HR', 'Engineering', 'Marketing', 'Finance'],
    'Location': ['New York', 'San Francisco', 'Chicago', 'Boston']
}).set_index('DepartmentID')
left_joined = employees.join(departments, how='left')
print(left_joined)
# Out:
#               EmployeeID     Name DepartmentName       Location
# DepartmentID
# 1                    101    Alice             HR       New York
# 2                    102      Bob    Engineering  San Francisco
# 3                    103  Charlie      Marketing        Chicago
# 5                    104    David            NaN            NaN

# %%
right_joined = employees.join(departments, how='right')
print(right_joined)
# Out:
#               EmployeeID     Name DepartmentName       Location
# DepartmentID
# 1                  101.0    Alice             HR       New York
# 2                  102.0      Bob    Engineering  San Francisco
# 3                  103.0  Charlie      Marketing        Chicago
# 4                    NaN      NaN        Finance         Boston

# %%
inner_joined = employees.join(departments, how='inner')
print(inner_joined)
# Out:
#               EmployeeID     Name DepartmentName       Location
# DepartmentID
# 1                    101    Alice             HR       New York
# 2                    102      Bob    Engineering  San Francisco
# 3                    103  Charlie      Marketing        Chicago

# %%
outer_joined = employees.join(departments, how='outer')
print(outer_joined)
# Out:
#               EmployeeID     Name DepartmentName       Location
# DepartmentID
# 1                  101.0    Alice             HR       New York
# 2                  102.0      Bob    Engineering  San Francisco
# 3                  103.0  Charlie      Marketing        Chicago
# 4                    NaN      NaN        Finance         Boston
# 5                  104.0    David            NaN            NaN

# %%
import os

# %%
new_dir_path = "Almabetter:/Student/Username/Documents/NewProject"
new_dir_name = "DataFiles"
